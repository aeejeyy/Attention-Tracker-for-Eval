# %%
import pandas as pd

# %%
df1=pd.read_csv('concentration_log_20250813_180527.csv')

# %%
df2=pd.read_csv('detailed_concentration_log_20250813_180527.csv')

# %%
df1.head()
# Out:
#              timestamp  concentration_score  gaze_score  head_pose_score  \
# 0  2025-08-13 18:05:38                   71    0.802433         0.000000
# 1  2025-08-13 18:05:38                   74    0.876828         0.000377
# 2  2025-08-13 18:05:39                   84    0.904429         0.356321
# 3  2025-08-13 18:05:39                   88    0.899261         0.327875
# 4  2025-08-13 18:05:40                   82    0.830839         0.084784
#
#    blink_detected  distraction_count  avg_ear   status  blink_rate_per_min  \
# 0            True                  0   0.1753  FOCUSED              1680.0
# 1            True                  0   0.1969  FOCUSED              1740.0
# 2           False                  0   0.2018  FOCUSED              1620.0
# 3            True                  0   0.1743  FOCUSED              1620.0
# 4            True                  0   0.1096  FOCUSED              1800.0
#
# ...

# %%
df2.head()
# Out:
#              timestamp  frame_number  left_ear  right_ear  avg_ear  \
# 0  2025-08-13 18:05:38            15    0.1276     0.2231   0.1753
# 1  2025-08-13 18:05:38            30    0.1916     0.2023   0.1969
# 2  2025-08-13 18:05:39            45    0.1903     0.2134   0.2018
# 3  2025-08-13 18:05:39            60    0.1690     0.1795   0.1743
# 4  2025-08-13 18:05:40            75    0.0807     0.1385   0.1096
#
#    left_eyebrow_height  right_eyebrow_height  mouth_aspect_ratio  nose_x  \
# 0               310.27                334.52              0.1675  345.08
# 1               290.42                289.51              0.1865  322.17
# 2               266.78                263.62              0.1689  321.55
# 3               260.97                261.96              0.1609  345.62
# 4               254.85                267.13              0.1574  394.09
#
#    nose_y  head_tilt_angle  left_iris_x  right_iris_x gaze_direction  \
# ...

# %%
import seaborn as sns

# %%
sns.pairplot(df1)

# %%
sns.pairplot(df2)
